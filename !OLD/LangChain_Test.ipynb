# %% [markdown]
# # LLM interpreter notebook
# This notebook is intended to cover the architechture of the LLM, which is to be used as a interpreter of SHAP/LIME values

# %%
import pandas as pd
import openpyxl as openpyxl
import numpy as np
# Out:
# C:\Users\josep\AppData\Local\Temp\ipykernel_27172\3326782321.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## Load SHAP dataframe

# %%
file_path = r"C:\Users\josep\OneDrive - Aarhus universitet\Speciale\Speciale---Stibo\shap_df_testset.csv"
shap_data = pd.read_csv(file_path)

# %%
shap_data.head()
# Out:
#    ChurnBaseValue  SeniorCitizen    tenure  MonthlyCharges  TotalCharges  \
# 0        0.262382            0.0 -0.031790       -0.012948     -0.004579
# 1        0.262382            0.0 -0.009395       -0.012948     -0.004579
# 2        0.262382            0.0  0.018750        0.011162     -0.000835
# 3        0.262382            0.0 -0.040295       -0.012948     -0.000835
# 4        0.262382            0.0  0.076218       -0.015844     -0.000835
#
#    gender_Male  Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 0          0.0    -0.002024        0.001736               0.0
# 1          0.0     0.001972        0.001736               0.0
# 2          0.0    -0.000383        0.003975               0.0
# 3          0.0    -0.000383        0.003975               0.0
# 4          0.0     0.000374        0.003975               0.0
#
#    MultipleLines_No phone service  ...  StreamingTV_No internet service  \
# 0                       -0.001683  ...                              0.0
# ...

# %% [markdown]
# ## Langchain test

# %%
pip install langchain
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/84.0 kB ? eta -:--:--
#      ---------------------------------------  81.9/84.0 kB 4.5 MB/s eta 0:00:01
#      ---------------------------------------- 84.0/84.0 kB 1.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      -------------------------------- ------- 41.0/50.7 kB ? eta -:--:--
#      -------------------------------------- 50.7/50.7 kB 860.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/817.0 kB ? eta -:--:--
#    ------------------ --------------------- 368.6/817.0 kB 7.6 MB/s eta 0:00:01
#    --------------------------------------  809.0/817.0 kB 10.2 MB/s eta 0:00:01
#    ---------------------------------------- 817.0/817.0 kB 7.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/365.3 kB ? eta -:--:--
#    --------------------------------------  358.4/365.3 kB 21.8 MB/s eta 0:00:01
# ...
